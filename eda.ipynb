# %% [markdown]
# ### EDA - Calorie Burning Regression Model

# %%
#imports
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split

# %%
directory = "datalake"
calorie = "calories.csv"
exercise = "exercise.csv"

calorie_path = os.path.join(directory, calorie)
exercise_path = os.path.join(directory, exercise)

calorie_df = pd.read_csv(calorie_path)
exercise_df = pd.read_csv(exercise_path)

# %%
consolidated_df = exercise_df.merge(calorie_df, on="User_ID")

# %%
consolidated_df.describe()
# Out:
#             User_ID           Age        Height        Weight      Duration  \
# count  1.500000e+04  15000.000000  15000.000000  15000.000000  15000.000000
# mean   1.497736e+07     42.789800    174.465133     74.966867     15.530600
# std    2.872851e+06     16.980264     14.258114     15.035657      8.319203
# min    1.000116e+07     20.000000    123.000000     36.000000      1.000000
# 25%    1.247419e+07     28.000000    164.000000     63.000000      8.000000
# 50%    1.499728e+07     39.000000    175.000000     74.000000     16.000000
# 75%    1.744928e+07     56.000000    185.000000     87.000000     23.000000
# max    1.999965e+07     79.000000    222.000000    132.000000     30.000000
#
#          Heart_Rate     Body_Temp      Calories
# count  15000.000000  15000.000000  15000.000000
# mean      95.518533     40.025453     89.539533
# std        9.583328      0.779230     62.456978
# min       67.000000     37.100000      1.000000
# 25%       88.000000     39.600000     35.000000
# 50%       96.000000     40.200000     79.000000
# 75%      103.000000     40.600000    138.000000
# max      128.000000     41.500000    314.000000

# %%
consolidated_df_ = consolidated_df.copy()
#consolidated_df_ = pd.get_dummies(consolidated_df_,columns=['Gender'], prefix=['Category'])
consolidated_df_['Gender'] = pd.factorize(consolidated_df_['Gender'])[0]
consolidated_df_
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363       0   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698       1   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863       0   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408       1   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927       1   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082       1   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577       1   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188       1   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037       0   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526       0   63   173.0    79.0      18.0        92.0       40.5
#
#        Calories
# 0         231.0
# 1          66.0
# 2          26.0
# 3          71.0
# 4          35.0
# ...         ...
# 14995      45.0
# 14996      23.0
# 14997      75.0
# 14998      11.0
# 14999      98.0
#
# [15000 rows x 9 columns]

# %%
sns.scatterplot(consolidated_df_, x="Height", y="Weight", hue="Gender")
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
features = consolidated_df_.select_dtypes(include='float').columns

plt.subplots(figsize=(15,10))
for i, col in enumerate(features):
    plt.subplot(2,3,i+1)
    sns.distplot(consolidated_df_[col])
plt.tight_layout()
plt.show()

# %%
consolidated_df_.corr()
# Out:
#              User_ID    Gender       Age    Height    Weight  Duration  \
# User_ID     1.000000  0.000687 -0.001827 -0.013520 -0.011603 -0.002751
# Gender      0.000687  1.000000 -0.003222 -0.710534 -0.783186 -0.003440
# Age        -0.001827 -0.003222  1.000000  0.009554  0.090094  0.013247
# Height     -0.013520 -0.710534  0.009554  1.000000  0.958451 -0.004625
# Weight     -0.011603 -0.783186  0.090094  0.958451  1.000000 -0.001884
# Duration   -0.002751 -0.003440  0.013247 -0.004625 -0.001884  1.000000
# Heart_Rate -0.000457 -0.011555  0.010482  0.000528  0.004311  0.852869
# Body_Temp   0.000923 -0.007264  0.013175  0.001200  0.004095  0.903167
# Calories   -0.001661 -0.022357  0.154395  0.017537  0.035481  0.955421
#
#             Heart_Rate  Body_Temp  Calories
# User_ID      -0.000457   0.000923 -0.001661
# Gender       -0.011555  -0.007264 -0.022357
# Age           0.010482   0.013175  0.154395
# Height        0.000528   0.001200  0.017537
# Weight        0.004311   0.004095  0.035481
# Duration      0.852869   0.903167  0.955421
# Heart_Rate    1.000000   0.771529  0.897882
# Body_Temp     0.771529   1.000000  0.824558
# Calories      0.897882   0.824558  1.000000

# %%
correlation_matrix = consolidated_df_.corr()
plt.figure(figsize=(18,10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

plt.title("Covariance Matrix")
plt.show()

# %% [markdown]
# ### Data Processing

# %%
from sklearn.preprocessing import StandardScaler

# Segregate the data (X, y, x_train, y_train, y_test)
scaler = StandardScaler()
X = consolidated_df_.drop(columns=["User_ID","Calories"])
y = consolidated_df_["Calories"]

X = scaler.fit_transform(X)
X
# Out:
# array([[-1.00709181,  1.48472604,  1.08958204, ...,  1.61912727,
#          0.98940395,  0.99402302],
#        [ 0.99295813, -1.34217934, -0.59372619, ..., -0.1839901 ,
#         -0.15846102,  0.3523425 ],
#        [-1.00709181,  1.5436199 ,  0.31806577, ..., -1.26586052,
#         -0.78456918, -1.70103518],
#        ...,
#        [ 0.99295813,  0.01237949, -1.08469109, ...,  0.05642555,
#         -0.57586646,  0.09567029],
#        [-1.00709181,  2.07366466,  1.29999557, ..., -1.62648399,
#         -1.20197462, -2.21437961],
#        [-1.00709181,  1.19025673, -0.10276129, ...,  0.2968412 ,
#         -0.36716374,  0.60901471]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# ### Training and Evaluating

# %%
from sklearn.svm import SVC
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score


models = [LinearRegression, Lasso, Ridge, SVR, SVC, XGBRegressor, DecisionTreeRegressor, RandomForestRegressor]
mae_scores = []
mse_scores = []
rmse_scores = []
r2_scores = []

for model in models:
    regressor = model().fit(X_train, y_train)
    y_pred = regressor.predict(X_test)
    
    mae_scores.append(mean_absolute_error(y_test, y_pred)) 
    mse_scores.append(mean_squared_error(y_test, y_pred)) 
    rmse_scores.append(mean_squared_error(y_test, y_pred, squared=False))
    r2_scores.append(r2_score(y_test, y_pred))

# %%
regression_metrics_df = pd.DataFrame({
    "Model": ["LinearRegression", "Lasso", "Ridge", "SVR", "SVC", "XGBRegressor", "DecisionTreeRegressor", "RandomForestRegressor"],
    "Mean Absolute Error": mae_scores,
    "Mean Squared Error": mse_scores,
    "Root Mean Squared Error": rmse_scores,
    "R-squared (R2)": r2_scores
})

regression_metrics_df.set_index('Model', inplace=True)
regression_metrics_df
# Out:
#                        Mean Absolute Error  Mean Squared Error  \
# Model
# LinearRegression                  8.453069          135.848112
# Lasso                             8.988296          156.502241
# Ridge                             8.452211          135.836640
# SVR                               2.551022           39.007507
# SVC                               7.951467          148.780800
# XGBRegressor                      1.571133            5.186318
# DecisionTreeRegressor             3.466933           28.807733
# RandomForestRegressor             1.799048            8.046792
#
#                        Root Mean Squared Error  R-squared (R2)
# Model
# LinearRegression                     11.655390        0.965254
# Lasso                                12.510086        0.959971
# Ridge                                11.654898        0.965257
# SVR                                   6.245599        0.990023
# SVC                                  12.197574        0.961946
# XGBRegressor                          2.277349        0.998673
# DecisionTreeRegressor                 5.367284        0.992632
# RandomForestRegressor                 2.836687        0.997942

# %%
from sklearn.pipeline import Pipeline

pipe = Pipeline([('scaler', StandardScaler()),('rf', RandomForestRegressor())])

# %%
from sklearn.preprocessing import StandardScaler

# Segregate the data (X, y, x_train, y_train, y_test)
X = consolidated_df_.drop(columns=["User_ID","Calories"])
y = consolidated_df_["Calories"]
X_train, X_test, y_train, y_test = train_test_split(X,y)

pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('rf', RandomForestRegressor())])

# %%
y_pred = pipe.predict(X_test)
# Evaluate the model
mse = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 1.7299680000000002
# R-squared: 0.9978674099351885

# %%
# pipe.predict([(0,29,182.0,90.0,30.0,110.0,39.0)])
pipe.predict([[0,70, 160.0, 110.0, 60.0, 120.0, 40.0]])
# Out:
# array([292.16])

# %% [markdown]
# ### Export the model

# %%
import pickle

with open('regression_pipeline-0.1.1.pkl', 'wb') as f:
    pickle.dump(pipe, f)

# %%
# Load the trained model
with open('regression_pipeline-0.1.1.pkl', 'rb') as model_file:
    loaded_model = pickle.load(model_file)
    
loaded_model.predict([[0,29,182.0,90.0,30.0,110.0,39.0]])
# Out:
# array([194.5])

# %%
loaded_model.predict([[0,70,160.0,110.0,60.0,120.0,40.0]])
# Out:
# array([292.16])
